# %%
from class_new import *
import class_new
import importlib
importlib.reload(class_new)
# Out:
# <module 'class_new' from 'C:\\Users\\cjg\\Desktop\\python_code\\2022spcup\\class_new.py'>

# %%
# import import_ipynb

import sys
#sys.path.append('C:/Users/GJ/PycharmProjects/2022SPCUP')

from class_new import *
import class_new
import importlib
importlib.reload(class_new)

import tensorflow as tf
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, recall_score, accuracy_score, precision_score

from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, UpSampling2D, Input, Convolution2D, Reshape

known_volume_path = 'E:\\spcup2022\\spcup_2022_training_part1'
unknown_volume_path = 'E:\\spcup2022\\spcup_2022_unseen_data'


rs = 10
known_path, known_labels = part2_file_path_list(known_volume_path,label = True)
unknown_path, unknown_labels = part2_file_path_list(unknown_volume_path,label = False)

# print(known_path)
print(known_labels.shape)
print(unknown_labels.shape)

all_path = np.concatenate((known_path,unknown_path),axis = 0)
all_labels = np.concatenate((known_labels,unknown_labels),axis = 0)
print(all_labels.shape)


##train set
# print('raw train_set_num :',len(labels))
X_train_path=all_path
y_train_raw=all_labels
# X_train_path, X_test_path, y_train_raw, y_test_raw = train_test_split(all_path,
#                                                                       all_labels, test_size=0.2,
#                                                                       stratify = all_labels, random_state=rs)


n_mels = 64
samplint_rate = 16000
# train = classes.data(X_train_path, y_train_raw, n_mels=n_mels, known = True)
# # X_train,y_train = train.extract_mel(sampling_rate,n_mels)

# test = classes.data(X_test_path, y_test_raw, n_mels=n_mels, known = True)
# # X_test,y_test = test.extract_mel(sampling_rate,n_mels)

# unseen = data(unknown_path, unknown_labels, n_mels=n_mels, known = False)

# n = -1

train = data(X_train_path,y_train_raw,n_mels=n_mels, known = True)

# test = data(X_test_path,y_test_raw, n_mels=n_mels, known = True)

train.extract_mel()
# test.extract_mel()

train.reshape_data()
# test.reshape_data()


# import pickle
# with open('part2_train_rs10_nmels64(train5000x4+unseen1000x4).p','wb') as f:
#     pickle.dump(train,f)
    
# with open('part2_test_rs10_nmels64(train5000x5+unseen1000x4).p','wb') as f:
#     pickle.dump(test,f)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19568\3673307173.py in <module>
#      25
#      26 rs = 10
# ---> 27 known_path, known_labels = part2_file_path_list(known_volume_path,label = True)
#      28 unknown_path, unknown_labels = part2_file_path_list(unknown_volume_path,label = False)
#      29
#
# ~\Desktop\python_code\2022spcup\class_new.py in part2_file_path_list(volume_path, label)
#     265                     #             print(filename)
#     266                     FilePathList.append(volume_path + '/' + filename)
# --> 267                     labels.append(int(filename[0]))
#     268                 # else:
#     269                 #     pd_label = pd.read_csv(volume_path + '/' + filename)
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
# # print(train_data.X_split.shape)
# np.save('part2_cnn_train_data_train(train24000(19200))',train.X_reshaped)
# np.save('part2_cnn_train_data_test(train24000(4800))',test.X_reshaped)
# np.save('part2_cnn_train_data_train(train24000(19200))_file_split_num',train.file_split_num)
# np.save('part2_cnn_train_data_test(train24000(4800))_file_split_num',test.file_split_num)

# %%
print(test_soft.shape)
print(y_test_raw)

test_data = pd.DataFrame(test_soft)
y_test_data = pd.DataFrame(y_test_raw)


sort_test = np.concatenate((test_soft[y_test_raw == 0],test_soft[y_test_raw == 1],test_soft[y_test_raw == 2],
                          test_soft[y_test_raw == 3],test_soft[y_test_raw == 4],test_soft[y_test_raw == 5]),axis = 0)

sort_y = np.concatenate((y_test_raw[y_test_raw == 0],y_test_raw[y_test_raw == 1],y_test_raw[y_test_raw == 2],
                          y_test_raw[y_test_raw == 3],y_test_raw[y_test_raw == 4],y_test_raw[y_test_raw == 5]),axis = 0)
                         
test_data = pd.DataFrame(sort_test)
y_test_data = pd.DataFrame(sort_y)
                        
dataframe = pd.concat([test_data,y_test_data],axis =1)
dataframe.head()
# sort_test = np.concatenate((test_soft[test.y_split == 0],mse_test[test.y_split == 1],mse_test[test.y_split == 2],
#                           mse_test[test.y_split == 3],mse_test[test.y_split == 4],mse_unseen),axis = 0)

import pandas as pd
dataframe.to_csv('part2_sort_test4800_before_softmax.csv')

print(test_soft.shape)
# Out:
# (4800, 6)
# [3 0 3 ... 2 3 2]
#            0         1        2          3        4        5  0
# 0  27.923611 -10.24041  3.37297 -14.518420 -0.03298  1.61664  0
# 1  33.389210 -10.11042  2.07186 -13.771770  0.47234  0.90537  0
# 2  20.265310  -5.81627  3.24517 -13.077560  2.87962 -2.03864  0
# 3  36.896870 -14.44131  4.90045 -14.386620 -3.87557  3.93026  0
# 4  35.944290 -12.05013  1.43356 -17.065741 -3.28322  3.10575  0

# %%
print(train.X_reshaped.shape)
print(test.X_reshaped.shape)
# Out:
# (124002, 64, 32, 1)
# (30844, 64, 32, 1)

# %%
# import pickle
# with open('part2_train_rs10_nmels128(train5000x4+unseen1000x4).p','wb') as f:
#     pickle.dump(train,f)
# with open('part2_testrs10_rs10_nmels128(train5000x5+unseen1000x4).p','wb') as f:
#     pickle.dump(test,f)



# # with open("part1_label6_train.p", 'rb') as f:
# #     train = pickle.load(f)
# # with open("part1_label6_test.p", 'rb') as f:
# #     test = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# <ipython-input-7-2f0c6edf6452> in <module>
#       1 import pickle
#       2 with open('part2_train_rs10_nmels128(train5000x4+unseen1000x4).p','wb') as f:
# ----> 3     pickle.dump(train,f)
#       4 with open('part2_testrs10_rs10_nmels128(train5000x5+unseen1000x4).p','wb') as f:
#       5     pickle.dump(test,f)
#
# PicklingError: Can't pickle <class 'class_new.data'>: it's not the same object as class_new.data

# %%
# X_train = train.X_reshaped
# X_test = test.X_reshaped
# y_train = train.y_reshaped
# y_test = test.y_reshaped
# print(y_train.shape)

# %%
X_train = train.X_reshaped
# X_test = test.X_reshaped
y_train = train.y_reshaped
# y_test = test.y_reshaped

for n_mels in [128]:
    for hop_length in [512]:
        for n_fft in [2048]:
            from tensorflow.keras.models import Sequential
            from tensorflow.keras.layers import Flatten, Conv2D, MaxPool2D
            from tensorflow.keras.callbacks import EarlyStopping
            from tensorflow.keras.callbacks import ModelCheckpoint

            print((X_train.shape[1:]))
            model = Sequential()

            #model 2
            model.add(layers.BatchNormalization(input_shape=(X_train.shape[1:])))
            model.add(layers.Conv2D(filters=16, kernel_size=(5, 5), padding="same", activation='relu'))
            model.add(layers.BatchNormalization())
            model.add(layers.Conv2D(filters=32, kernel_size=(5, 5), padding="same", activation='relu'))
            model.add(layers.BatchNormalization())
            model.add(layers.Conv2D(filters=64, kernel_size=(5, 5), padding="same", activation='relu'))
            model.add(MaxPool2D(pool_size=(5, 5)))
            model.add(Flatten())
            model.add(layers.Dense(6, activation=None))
            model.add(layers.Activation('softmax'))


            # 모델 컴파일
            model.compile(optimizer='adam',
                          loss='categorical_crossentropy',
                          metrics=['accuracy'])


            callbacks = [EarlyStopping(monitor='val_loss', min_delta=0, patience=100, mode='auto',restore_best_weights=True), 
                         ModelCheckpoint(filepath=str(n_mels)+"_"+str(hop_length)+"_"+ str(rs) + "_"
                                         + "part2_mel_feature128_label_6_model.h5",
                                         monitor='val_loss', verbose=0, save_best_only=True)]

            classifier = model.fit(X_train,
                                   y_train,
                                   epochs=1000,
                                   batch_size=64, callbacks=callbacks) 

#             model_json = model.to_json()
#             with open("./models_log" + "/" + str(rs) + "_" + "spcup.json", 'w') as json_file:
#                 json_file.write(model_json)
            #             model.save_weights("./models_log" + "/" + str(rs) + "_" + "spcup.h5")
            print("Saved model to disk")


            #             #### json 모델 load
            #             from keras.models import model_from_json
            #             json_file = open("model.json", "r") 
            #             loaded_model_json = json_file.read() 
            #             json_file.close() 
            #             loaded_model = model_from_json(loaded_model_json)

            plt.plot(classifier.history['accuracy'])
            # plt.plot(classifier.history['val_accuracy'])
            plt.plot(classifier.history['loss'])
            # plt.plot(classifier.history['val_loss'])
            plt.legend([ 'Train accuracy','Train loss'], loc = 'upper left')
            plt.show()

            test_loss, test_acc = model.evaluate(X_test,  y_test, verbose=2)

            print('테스트 정확도:', test_acc)

            prediction = model.predict(X_test)




            # #######################segment들 합쳐서 파일당 accuracy 계산
            # from scipy.stats import mode
            # predicted_classes = np.argmax(prediction, axis = 1)
            # f = 0
            # test_predict=[]
            # for i in file_split_num:
            # #     print(predicted_classes[f:f+i])
            #     test_predict.append(mode(predicted_classes[f:f+i])[0][0])
            #     f+=i

            # acc_bool = test_predict==y_test_raw
            # #             print(test_predict[:100])
            # #             print(y_test_raw[:100])
            # #             print(acc_bool[:100])
            # test_accuracy = acc_bool.tolist().count(True)/len(acc_bool)
            # print('************ mel_spectogram')
            # print('************ file test_accuracy : ', test_accuracy, '  n_mels : ', n_mels,
            #       ', hop_length = ', hop_length,' , n_fft : ',n_fft)
            # print('************ X_train.shape : ', X_train.shape)
            # print('test_set.size : ', acc_bool.size)
            # print('\n\n\n')

            # df.append({'n_mels':n_mels,'hop_length':hop_length,'n_fft':n_fft,'rs':rs,'accuracy':test_accuracy,'input_shape':X_train.shape},ignore_index = True)
            # df.to_csv("models_log.csv",sep=",")
# Out:
# (64, 32, 1)
# Epoch 1/1000
# 1210/1210 [==============================] - 34s 26ms/step - loss: 0.4699 - accuracy: 0.8183
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 145/1000
# 1210/1210 [==============================] - 31s 25ms/step - loss: 0.0069 - accuracy: 0.9982
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 146/1000
# 1210/1210 [==============================] - 30s 24ms/step - loss: 0.0048 - accuracy: 0.9988
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 147/1000
# 1210/1210 [==============================] - 29s 24ms/step - loss: 0.0057 - accuracy: 0.9985
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 148/1000
# 1210/1210 [==============================] - 30s 24ms/step - loss: 0.0056 - accuracy: 0.9985
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 149/1000
# 1210/1210 [==============================] - 30s 25ms/step - loss: 0.0052 - accuracy: 0.9985
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 150/1000
# 1210/1210 [==============================] - 31s 26ms/step - loss: 0.0069 - accuracy: 0.9984
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 151/1000
# 1210/1210 [==============================] - 30s 25ms/step - loss: 0.0043 - accuracy: 0.9989
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 152/1000
# 1210/1210 [==============================] - 30s 25ms/step - loss: 0.0067 - accuracy: 0.9983
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 153/1000
# 1210/1210 [==============================] - 29s 24ms/step - loss: 0.0052 - accuracy: 0.9986
# ...
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 952/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0103 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 953/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0120 - accuracy: 0.9996
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 954/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0101 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 955/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0117 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 956/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0094 - accuracy: 0.9998
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 957/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0133 - accuracy: 0.9996
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 958/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0070 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 959/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0111 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 960/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0072 - accuracy: 0.9998
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 961/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0178 - accuracy: 0.9995
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 962/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0100 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 963/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0093 - accuracy: 0.9998
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 964/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0115 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 965/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0083 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 966/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0161 - accuracy: 0.9996
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 967/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0077 - accuracy: 0.9998
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 968/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0137 - accuracy: 0.9996
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 969/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0111 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 970/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0100 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 971/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0110 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 972/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0089 - accuracy: 0.9998
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 973/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0176 - accuracy: 0.9995
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 974/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0088 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 975/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0108 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 976/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0114 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 977/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0127 - accuracy: 0.9996
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 978/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0085 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 979/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0146 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 980/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0098 - accuracy: 0.9996
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 981/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0063 - accuracy: 0.9998
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 982/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0148 - accuracy: 0.9995
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 983/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0090 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 984/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0085 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 985/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0125 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 986/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0117 - accuracy: 0.9996
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 987/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0085 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 988/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0085 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 989/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0146 - accuracy: 0.9996
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 990/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0064 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 991/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0079 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 992/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0148 - accuracy: 0.9996
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 993/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0096 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 994/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0107 - accuracy: 0.9996
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 995/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0090 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 996/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0062 - accuracy: 0.9998
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 997/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0127 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 998/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0105 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 999/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0061 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 1000/1000
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.0098 - accuracy: 0.9997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Saved model to disk
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17804\3398717404.py in <module>
#      65             plt.show()
#      66
# ---> 67             test_loss, test_acc = model.evaluate(X_test,  y_test, verbose=2)
#      68
#      69             print('테스트 정확도:', test_acc)
#
# NameError: name 'X_test' is not defined

# %%
model.save("./best_model_noise" + "/" + str(rs) + "_" + "part2_label6_spcup_save_last.h5")

# %%
from sklearn.metrics import confusion_matrix
cf = confusion_matrix(y_test_raw, test_predict)
print('\n\n', cf)
# Out:
#  [[800   0   0   0   0   0]
#  [  0 797   3   0   0   0]
#  [  0  15 781   0   0   4]
#  [  0   0   0 800   0   0]
#  [  0   0   0   0 800   0]
#  [  0   0   0   0   0 800]]

# %%
num = 0
idx_p = []
for idx, i in enumerate(X_test_path):
    if ("noise"  not in i) and ("reverb" not in i) and ("compressed" not in i):
        idx_p.append(idx)
        num+=1
print(num)
# Out:
# 1238

# %%
model = load_model('./best_model_noise/10_part2_label6_spcup_save_last.h5')

# %%
X_test_path[idx_p]
y_test_raw[idx_p]

from sklearn.metrics import confusion_matrix
cf = confusion_matrix(y_test_raw[idx_p], test_predict[idx_p])
print('\n\n', cf)
# Out:
#  [[216   0   0   0   0   0]
#  [  0 187   0   0   0   0]
#  [  0   0 215   0   0   0]
#  [  0   0   0 208   0   0]
#  [  0   0   0   0 220   0]
#  [  0   0   0   0   0 192]]

# %%
from tensorflow.keras.models import load_model

# model = load_model('./64_1024_10_part2_mel_feature_label_6_model.h5')
model = load_model('./best_model_noise/10_part2_label6_spcup_save_last.h5')

# model_vec = load_model('./64_1024_10_part2_mel_feature_label_6_model.h5')
model_vec = load_model('./best_model_noise/10_part2_label6_spcup_save_last.h5')

model_vec.pop()
model_vec.compile()
model_vec.summary()

def ext_soft(data, model, model_vec, n_round = 5):
    

    
    prediction_soft = model.predict(data.X_reshaped)
    prediction_vec = model_vec.predict(data.X_reshaped)
    predicted_classes = np.argmax(prediction_soft, axis=1)
    

    
    f = 0
    softmax_val = []
    test_predict = []

    for j,i in enumerate(data.file_split_num):
        mean_vec = np.mean(prediction_vec[f:f + i],axis = 0)    
        mean_soft = np.mean(prediction_soft[f:f + i],axis = 0) 
#         mean_soft = np.mean(prediction[f:f + i],axis = 0)
#         mean_soft = np.mean(np.power(prediction[f:f + i],2),axis = 0)
        
        softmax_val.append(np.round(mean_vec,n_round))
#         test_predict.append(mode(predicted_classes[f:f + i])[0][0])
        test_predict.append(np.argmax(mean_soft))
        
#         predicted_classes = np.argmax(np.mean(np.power(prediction[f:f + i],1),axis = 0))
#         test_predict.append(predicted_classes)
        f += i
    return np.array(softmax_val), np.array(test_predict)

soft_val, test_predict = ext_soft(test,model,model_vec, 5)

# %%
y_test_raw[:-1].shape

# %%
from sklearn.metrics import confusion_matrix
cf = confusion_matrix(np.array(y_test_raw)[:-1], test_predict)
print('\n\n', cf)

# %%
 #######################segment들 합쳐서 파일당 accuracy 계산
from scipy.stats import mode
predicted_classes = np.argmax(prediction, axis = 1)
f = 0
test_predict=[]
for i in test.file_split_num:
#     print(predicted_classes[f:f+i])
    test_predict.append(mode(predicted_classes[f:f+i])[0][0])
#     print(test_predict)
    f+=i

test_predict = np.array(test_predict)
print(len(test.file_split_num))
print(test_predict.shape)
print(y_test_raw.shape)


acc_bool = test_predict==y_test_raw[:-1]
print(acc_bool)
#             print(test_predict[:100])
#             print(y_test_raw[:100])
#             print(acc_bool[:100])
test_accuracy = acc_bool.tolist().count(True)/len(acc_bool)
print('************ mel_spectogram')
print('************ file test_accuracy : ', test_accuracy, '  n_mels : ', n_mels,
      ', hop_length = ', hop_length,' , n_fft : ',n_fft)
print('************ X_train.shape : ', X_train.shape)
print('test_set.size : ', acc_bool.size)
print('\n\n\n')
print('saved_mdel_name : ', "./models_log" + "/" +str(n_mels)+"_"+str(hop_length)+"_"+ str(rs) + "_"
                                         + "othre_feature_label_6_model.h5" )
# df.append({'n_mels':n_mels,'hop_length':hop_length,'n_fft':n_fft,'rs':rs,'accuracy':test_accuracy,'input_shape':X_train.shape},ignore_index = True)
# df.to_csv("models_log.csv",sep=",")

from sklearn.metrics import confusion_matrix
cf = confusion_matrix(y_test_raw[:-1], test_predict)
print('\n\n', cf)
